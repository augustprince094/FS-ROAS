# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import joblib
import os
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
import random
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# ---------------------------
# 1. Load and Preprocess Data
# ---------------------------

# Load data
# Use pd.read_excel() since the file is an Excel file (.xlsx)
df = pd.read_excel("/content/Data_GHGE.xlsx")

# Feature selection
feature_columns = [
   'FP index ', 'LP index ', 'Vegetal Pds-FS', 'Cereals -FS',
       'Starchy Rts-FS', 'Pulses-FS', 'Fruits -FS', 'Meat-FS', 'Fish-FS',
       'Sugar & Swt-FS', 'Oils-FS ', 'Vegetables-FS ', 'Spices-FS', 'Eggs-FS',
       'Milk-FS', 'Cereals-LSF', 'Starchy Rts-LSF', 'Pulses-LSF', 'Meat-LSF',
       'Fish-LSF', 'Cereals-LS', 'Starchy-LS', 'Fruits-LS', 'Energy use',
       'Renewable energy '
]

# %%
df.columns
# Out:
# Index(['Indicator Code', 'FP index ', 'LP index ', 'Vegetal Pds-FS',
#        'Cereals -FS', 'Starchy Rts-FS', 'Pulses-FS', 'Fruits -FS', 'Meat-FS',
#        'Fish-FS', 'Sugar & Swt-FS', 'Oils-FS ', 'Vegetables-FS ', 'Spices-FS',
#        'Eggs-FS', 'Milk-FS', 'Cereals-LSF', 'Starchy Rts-LSF', 'Pulses-LSF',
#        'Meat-LSF', 'Fish-LSF', 'Cereals-LS', 'Starchy-LS', 'Fruits-LS',
#        'Energy use', 'Renewable energy ', 'GHGEs ',
#        'Agricultural land use share ', 'Agricultural water share ',
#        'Surface temp.', 'Overweight', 'Obese', 'Death-NCD ',
#        'Life expectancy '],
#       dtype='object')

# %%
X = df[feature_columns].values
# Health indicators
# y = df['Overweight'].values
# y = df ['Obese'].values
y = df['Death-NCD '].values
# y = df[  'Life expectancy '].values



# y = df['GHGEs '].values
# y = df['Agricultural land use share '].values
# y = df['Agricultural water share '].values
# y = df[ 'Surface temp.'].values








# Split data before scaling to prevent data leakage


X_train_raw= X[:51]
X_test_raw = X[51:]
y_train_raw= y[:51]
y_test_raw= y[51:]



# x_train = X_x[:52]
# x_test = X_x[52:]
# y_train = Y_data[:52]
# y_test = Y_data[52:]






# Initialize scalers
feature_scaler = RobustScaler()
target_scaler = RobustScaler()
# from sklearn.preprocessing import StandardScaler
# feature_scaler = StandardScaler()
# target_scaler = StandardScaler()

# %%
y_test_raw
# Out:
# array([30.96125 , 30.840206, 30.755196, 30.83819 , 30.633383, 30.534817,
#        30.59448 , 30.099432, 26.97264 , 27.372815])

# %%
# Fit scalers on training data
X_train_scaled = feature_scaler.fit_transform(X_train_raw)
y_train_scaled = target_scaler.fit_transform(y_train_raw.reshape(-1, 1))

# Transform test data
X_test_scaled = feature_scaler.transform(X_test_raw)
y_test_scaled = target_scaler.transform(y_test_raw.reshape(-1, 1))

# Create sequences
def create_sequences(X, y, sequence_length=3):
    sequences_X = []
    sequences_y = []
    for i in range(len(X) - sequence_length + 1):
        sequences_X.append(X[i:i+sequence_length])
        sequences_y.append(y[i+sequence_length-1])
    return np.array(sequences_X), np.array(sequences_y)

# Create sequences in training data
X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_scaled, sequence_length=3)

# Create sequences in test data
X_test_seq, y_test_seq = create_sequences(X_test_scaled, y_test_scaled, sequence_length=3)

# %%
# 2. Build the Bidirectional LSTM Model
# ---------------------------

from tensorflow.keras.layers import Bidirectional

# Build the model
model = Sequential([
    Bidirectional(LSTM(64, return_sequences=True, kernel_regularizer=l2(0.001)),
                  input_shape=(X_train_seq.shape[1], X_train_seq.shape[2])),
    Dropout(0.3),

    Bidirectional(LSTM(32, return_sequences=False, kernel_regularizer=l2(0.001))),
    Dropout(0.3),

    Dense(16, activation='relu', kernel_regularizer=l2(0.001)),
    Dense(1, activation='linear')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#  Define custom metric
def correlation_coefficient(y_true, y_pred):
    x = y_true - K.mean(y_true)
    y = y_pred - K.mean(y_pred)
    numerator = K.sum(x * y)
    denominator = K.sqrt(K.sum(K.square(x)) * K.sum(K.square(y)))
    return numerator / (denominator + K.epsilon())

# Compile the model
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mean_squared_error',
    metrics=['mae', correlation_coefficient]
)

# %%
# 4. Train the Model
# ---------------------------

# Callbacks
callbacks = [
    EarlyStopping(monitor='val_correlation_coefficient', mode='max', patience=20, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-5)
]

# Train the model
history = model.fit(
    X_train_seq, y_train_seq,
    validation_data=(X_test_seq, y_test_seq),
    epochs=700,
    batch_size=16,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 402ms/step - correlation_coefficient: 0.2542 - loss: 0.7218 - mae: 0.4845 - val_correlation_coefficient: -0.6236 - val_loss: 1.5017 - val_mae: 1.0594 - learning_rate: 0.0010
# Epoch 2/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - correlation_coefficient: 0.8179 - loss: 0.5110 - mae: 0.2893 - val_correlation_coefficient: -0.4845 - val_loss: 0.8438 - val_mae: 0.6896 - learning_rate: 0.0010
# Epoch 3/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8469 - loss: 0.4186 - mae: 0.1840 - val_correlation_coefficient: -0.4998 - val_loss: 0.4607 - val_mae: 0.3213 - learning_rate: 0.0010
# Epoch 4/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8747 - loss: 0.3653 - mae: 0.1381 - val_correlation_coefficient: -0.4485 - val_loss: 0.3470 - val_mae: 0.1067 - learning_rate: 0.0010
# Epoch 5/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8570 - loss: 0.3725 - mae: 0.1703 - val_correlation_coefficient: -0.4256 - val_loss: 0.3465 - val_mae: 0.1720 - learning_rate: 0.0010
# Epoch 6/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8666 - loss: 0.3474 - mae: 0.1506 - val_correlation_coefficient: -0.3861 - val_loss: 0.3368 - val_mae: 0.1752 - learning_rate: 0.0010
# Epoch 7/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8767 - loss: 0.3295 - mae: 0.1351 - val_correlation_coefficient: -0.3372 - val_loss: 0.3188 - val_mae: 0.1570 - learning_rate: 0.0010
# Epoch 8/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8845 - loss: 0.3079 - mae: 0.1091 - val_correlation_coefficient: -0.2649 - val_loss: 0.3096 - val_mae: 0.1593 - learning_rate: 0.0010
# Epoch 9/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - correlation_coefficient: 0.8736 - loss: 0.3010 - mae: 0.1172 - val_correlation_coefficient: -0.1584 - val_loss: 0.3048 - val_mae: 0.1688 - learning_rate: 0.0010
# Epoch 10/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8874 - loss: 0.2843 - mae: 0.0929 - val_correlation_coefficient: -0.0805 - val_loss: 0.3137 - val_mae: 0.2043 - learning_rate: 0.0010
# Epoch 11/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8866 - loss: 0.2813 - mae: 0.1055 - val_correlation_coefficient: -0.0750 - val_loss: 0.3553 - val_mae: 0.2911 - learning_rate: 0.0010
# Epoch 12/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - correlation_coefficient: 0.8802 - loss: 0.2762 - mae: 0.1224 - val_correlation_coefficient: -0.0383 - val_loss: 0.3491 - val_mae: 0.2965 - learning_rate: 0.0010
# Epoch 13/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8865 - loss: 0.2545 - mae: 0.0899 - val_correlation_coefficient: -0.0140 - val_loss: 0.3175 - val_mae: 0.2563 - learning_rate: 0.0010
# Epoch 14/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8853 - loss: 0.2446 - mae: 0.0819 - val_correlation_coefficient: -0.0233 - val_loss: 0.2886 - val_mae: 0.2235 - learning_rate: 0.0010
# Epoch 15/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8824 - loss: 0.2405 - mae: 0.0901 - val_correlation_coefficient: -0.0039 - val_loss: 0.2752 - val_mae: 0.2135 - learning_rate: 0.0010
# Epoch 16/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8817 - loss: 0.2334 - mae: 0.0976 - val_correlation_coefficient: 0.0156 - val_loss: 0.2472 - val_mae: 0.1695 - learning_rate: 0.0010
# Epoch 17/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - correlation_coefficient: 0.8947 - loss: 0.2142 - mae: 0.0540 - val_correlation_coefficient: 0.0250 - val_loss: 0.2260 - val_mae: 0.1380 - learning_rate: 0.0010
# Epoch 18/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - correlation_coefficient: 0.8823 - loss: 0.2230 - mae: 0.1134 - val_correlation_coefficient: 0.0383 - val_loss: 0.2191 - val_mae: 0.1376 - learning_rate: 0.0010
# Epoch 19/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8927 - loss: 0.2017 - mae: 0.0659 - val_correlation_coefficient: 0.0267 - val_loss: 0.2180 - val_mae: 0.1518 - learning_rate: 0.0010
# Epoch 20/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8895 - loss: 0.2008 - mae: 0.0872 - val_correlation_coefficient: 0.0028 - val_loss: 0.2146 - val_mae: 0.1585 - learning_rate: 0.0010
# Epoch 21/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8845 - loss: 0.1947 - mae: 0.0765 - val_correlation_coefficient: 0.0177 - val_loss: 0.2097 - val_mae: 0.1598 - learning_rate: 0.0010
# Epoch 22/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8919 - loss: 0.1852 - mae: 0.0692 - val_correlation_coefficient: 0.0800 - val_loss: 0.1956 - val_mae: 0.1381 - learning_rate: 0.0010
# Epoch 23/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8904 - loss: 0.1822 - mae: 0.0722 - val_correlation_coefficient: 0.1432 - val_loss: 0.1819 - val_mae: 0.1007 - learning_rate: 0.0010
# Epoch 24/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - correlation_coefficient: 0.8895 - loss: 0.1748 - mae: 0.0680 - val_correlation_coefficient: 0.1754 - val_loss: 0.1772 - val_mae: 0.0894 - learning_rate: 0.0010
# Epoch 25/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8929 - loss: 0.1710 - mae: 0.0691 - val_correlation_coefficient: 0.1757 - val_loss: 0.1718 - val_mae: 0.0955 - learning_rate: 0.0010
# Epoch 26/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - correlation_coefficient: 0.8931 - loss: 0.1647 - mae: 0.0685 - val_correlation_coefficient: 0.1876 - val_loss: 0.1680 - val_mae: 0.1041 - learning_rate: 0.0010
# Epoch 27/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8910 - loss: 0.1623 - mae: 0.0777 - val_correlation_coefficient: 0.1951 - val_loss: 0.1680 - val_mae: 0.1236 - learning_rate: 0.0010
# Epoch 28/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - correlation_coefficient: 0.8916 - loss: 0.1568 - mae: 0.0701 - val_correlation_coefficient: 0.1989 - val_loss: 0.1746 - val_mae: 0.1518 - learning_rate: 0.0010
# Epoch 29/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - correlation_coefficient: 0.8896 - loss: 0.1530 - mae: 0.0649 - val_correlation_coefficient: 0.2537 - val_loss: 0.1807 - val_mae: 0.1775 - learning_rate: 0.0010
# Epoch 30/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8888 - loss: 0.1512 - mae: 0.0806 - val_correlation_coefficient: 0.3003 - val_loss: 0.1669 - val_mae: 0.1512 - learning_rate: 0.0010
# Epoch 31/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8916 - loss: 0.1479 - mae: 0.0792 - val_correlation_coefficient: 0.3249 - val_loss: 0.1505 - val_mae: 0.1095 - learning_rate: 0.0010
# Epoch 32/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - correlation_coefficient: 0.8910 - loss: 0.1420 - mae: 0.0715 - val_correlation_coefficient: 0.3371 - val_loss: 0.1446 - val_mae: 0.1022 - learning_rate: 0.0010
# Epoch 33/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - correlation_coefficient: 0.8857 - loss: 0.1430 - mae: 0.0875 - val_correlation_coefficient: 0.3834 - val_loss: 0.1405 - val_mae: 0.0984 - learning_rate: 0.0010
# Epoch 34/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8926 - loss: 0.1336 - mae: 0.0667 - val_correlation_coefficient: 0.4508 - val_loss: 0.1370 - val_mae: 0.0958 - learning_rate: 0.0010
# Epoch 35/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8899 - loss: 0.1330 - mae: 0.0666 - val_correlation_coefficient: 0.5032 - val_loss: 0.1395 - val_mae: 0.1135 - learning_rate: 0.0010
# Epoch 36/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8889 - loss: 0.1328 - mae: 0.0811 - val_correlation_coefficient: 0.5284 - val_loss: 0.1572 - val_mae: 0.1728 - learning_rate: 0.0010
# Epoch 37/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - correlation_coefficient: 0.8929 - loss: 0.1257 - mae: 0.0609 - val_correlation_coefficient: 0.5306 - val_loss: 0.1493 - val_mae: 0.1607 - learning_rate: 0.0010
# Epoch 38/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8944 - loss: 0.1202 - mae: 0.0552 - val_correlation_coefficient: 0.5201 - val_loss: 0.1360 - val_mae: 0.1301 - learning_rate: 0.0010
# Epoch 39/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8931 - loss: 0.1184 - mae: 0.0562 - val_correlation_coefficient: 0.5083 - val_loss: 0.1242 - val_mae: 0.0948 - learning_rate: 0.0010
# Epoch 40/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - correlation_coefficient: 0.8927 - loss: 0.1181 - mae: 0.0651 - val_correlation_coefficient: 0.4885 - val_loss: 0.1226 - val_mae: 0.0971 - learning_rate: 0.0010
# Epoch 41/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8889 - loss: 0.1188 - mae: 0.0767 - val_correlation_coefficient: 0.4905 - val_loss: 0.1339 - val_mae: 0.1457 - learning_rate: 0.0010
# Epoch 42/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8951 - loss: 0.1110 - mae: 0.0557 - val_correlation_coefficient: 0.4932 - val_loss: 0.1346 - val_mae: 0.1534 - learning_rate: 0.0010
# Epoch 43/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - correlation_coefficient: 0.8919 - loss: 0.1108 - mae: 0.0624 - val_correlation_coefficient: 0.4775 - val_loss: 0.1341 - val_mae: 0.1576 - learning_rate: 0.0010
# Epoch 44/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - correlation_coefficient: 0.8940 - loss: 0.1085 - mae: 0.0558 - val_correlation_coefficient: 0.4621 - val_loss: 0.1294 - val_mae: 0.1506 - learning_rate: 0.0010
# Epoch 45/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8957 - loss: 0.1045 - mae: 0.0492 - val_correlation_coefficient: 0.4394 - val_loss: 0.1132 - val_mae: 0.1010 - learning_rate: 0.0010
# Epoch 46/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8929 - loss: 0.1042 - mae: 0.0604 - val_correlation_coefficient: 0.4244 - val_loss: 0.1091 - val_mae: 0.0860 - learning_rate: 0.0010
# Epoch 47/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8946 - loss: 0.1031 - mae: 0.0606 - val_correlation_coefficient: 0.4396 - val_loss: 0.1063 - val_mae: 0.0859 - learning_rate: 0.0010
# Epoch 48/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - correlation_coefficient: 0.8924 - loss: 0.1050 - mae: 0.0835 - val_correlation_coefficient: 0.4830 - val_loss: 0.1072 - val_mae: 0.0980 - learning_rate: 0.0010
# Epoch 49/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8919 - loss: 0.0996 - mae: 0.0626 - val_correlation_coefficient: 0.5082 - val_loss: 0.1209 - val_mae: 0.1490 - learning_rate: 0.0010
# Epoch 50/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8929 - loss: 0.1005 - mae: 0.0762 - val_correlation_coefficient: 0.5110 - val_loss: 0.1046 - val_mae: 0.0987 - learning_rate: 0.0010
# Epoch 51/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8885 - loss: 0.1000 - mae: 0.0772 - val_correlation_coefficient: 0.5176 - val_loss: 0.0990 - val_mae: 0.0842 - learning_rate: 0.0010
# Epoch 52/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - correlation_coefficient: 0.8944 - loss: 0.0977 - mae: 0.0748 - val_correlation_coefficient: 0.5363 - val_loss: 0.0976 - val_mae: 0.0841 - learning_rate: 0.0010
# Epoch 53/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - correlation_coefficient: 0.8913 - loss: 0.0951 - mae: 0.0692 - val_correlation_coefficient: 0.5811 - val_loss: 0.1002 - val_mae: 0.1007 - learning_rate: 0.0010
# Epoch 54/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - correlation_coefficient: 0.8911 - loss: 0.0946 - mae: 0.0740 - val_correlation_coefficient: 0.6190 - val_loss: 0.1206 - val_mae: 0.1642 - learning_rate: 0.0010
# Epoch 55/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8901 - loss: 0.0949 - mae: 0.0822 - val_correlation_coefficient: 0.6318 - val_loss: 0.1049 - val_mae: 0.1236 - learning_rate: 0.0010
# Epoch 56/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8912 - loss: 0.0915 - mae: 0.0674 - val_correlation_coefficient: 0.6404 - val_loss: 0.0967 - val_mae: 0.1022 - learning_rate: 0.0010
# Epoch 57/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - correlation_coefficient: 0.8939 - loss: 0.0866 - mae: 0.0530 - val_correlation_coefficient: 0.6501 - val_loss: 0.0932 - val_mae: 0.0937 - learning_rate: 0.0010
# Epoch 58/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8959 - loss: 0.0843 - mae: 0.0465 - val_correlation_coefficient: 0.6482 - val_loss: 0.0918 - val_mae: 0.0926 - learning_rate: 0.0010
# Epoch 59/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8958 - loss: 0.0836 - mae: 0.0517 - val_correlation_coefficient: 0.6530 - val_loss: 0.0989 - val_mae: 0.1172 - learning_rate: 0.0010
# Epoch 60/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8919 - loss: 0.0845 - mae: 0.0626 - val_correlation_coefficient: 0.6506 - val_loss: 0.1102 - val_mae: 0.1522 - learning_rate: 0.0010
# Epoch 61/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8946 - loss: 0.0882 - mae: 0.0735 - val_correlation_coefficient: 0.6456 - val_loss: 0.0864 - val_mae: 0.0828 - learning_rate: 0.0010
# Epoch 62/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - correlation_coefficient: 0.8884 - loss: 0.0851 - mae: 0.0716 - val_correlation_coefficient: 0.6191 - val_loss: 0.0877 - val_mae: 0.0933 - learning_rate: 0.0010
# Epoch 63/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8949 - loss: 0.0801 - mae: 0.0536 - val_correlation_coefficient: 0.5960 - val_loss: 0.0877 - val_mae: 0.0941 - learning_rate: 0.0010
# Epoch 64/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8925 - loss: 0.0821 - mae: 0.0704 - val_correlation_coefficient: 0.6003 - val_loss: 0.0827 - val_mae: 0.0843 - learning_rate: 0.0010
# Epoch 65/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - correlation_coefficient: 0.8932 - loss: 0.0786 - mae: 0.0611 - val_correlation_coefficient: 0.6075 - val_loss: 0.0811 - val_mae: 0.0785 - learning_rate: 0.0010
# Epoch 66/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.8932 - loss: 0.0785 - mae: 0.0606 - val_correlation_coefficient: 0.6227 - val_loss: 0.0846 - val_mae: 0.0971 - learning_rate: 0.0010
# Epoch 67/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8933 - loss: 0.0811 - mae: 0.0843 - val_correlation_coefficient: 0.6306 - val_loss: 0.1051 - val_mae: 0.1600 - learning_rate: 0.0010
# Epoch 68/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8907 - loss: 0.0776 - mae: 0.0661 - val_correlation_coefficient: 0.6315 - val_loss: 0.1072 - val_mae: 0.1684 - learning_rate: 0.0010
# Epoch 69/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - correlation_coefficient: 0.8910 - loss: 0.0771 - mae: 0.0704 - val_correlation_coefficient: 0.6300 - val_loss: 0.0923 - val_mae: 0.1275 - learning_rate: 0.0010
# Epoch 70/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8944 - loss: 0.0738 - mae: 0.0587 - val_correlation_coefficient: 0.6233 - val_loss: 0.0803 - val_mae: 0.0933 - learning_rate: 0.0010
# Epoch 71/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8934 - loss: 0.0728 - mae: 0.0580 - val_correlation_coefficient: 0.6297 - val_loss: 0.0753 - val_mae: 0.0771 - learning_rate: 0.0010
# Epoch 72/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8928 - loss: 0.0731 - mae: 0.0685 - val_correlation_coefficient: 0.6434 - val_loss: 0.0763 - val_mae: 0.0848 - learning_rate: 0.0010
# Epoch 73/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - correlation_coefficient: 0.8924 - loss: 0.0732 - mae: 0.0513 - val_correlation_coefficient: 0.6658 - val_loss: 0.0993 - val_mae: 0.1595 - learning_rate: 0.0010
# Epoch 74/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8936 - loss: 0.0706 - mae: 0.0604 - val_correlation_coefficient: 0.6791 - val_loss: 0.1154 - val_mae: 0.2049 - learning_rate: 0.0010
# Epoch 75/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8928 - loss: 0.0709 - mae: 0.0643 - val_correlation_coefficient: 0.6826 - val_loss: 0.0936 - val_mae: 0.1456 - learning_rate: 0.0010
# Epoch 76/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8940 - loss: 0.0709 - mae: 0.0695 - val_correlation_coefficient: 0.6748 - val_loss: 0.0735 - val_mae: 0.0864 - learning_rate: 0.0010
# Epoch 77/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - correlation_coefficient: 0.8937 - loss: 0.0686 - mae: 0.0608 - val_correlation_coefficient: 0.6788 - val_loss: 0.0743 - val_mae: 0.0937 - learning_rate: 0.0010
# Epoch 78/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - correlation_coefficient: 0.8936 - loss: 0.0694 - mae: 0.0670 - val_correlation_coefficient: 0.6917 - val_loss: 0.0883 - val_mae: 0.1370 - learning_rate: 0.0010
# Epoch 79/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - correlation_coefficient: 0.8920 - loss: 0.0680 - mae: 0.0551 - val_correlation_coefficient: 0.7038 - val_loss: 0.1258 - val_mae: 0.2375 - learning_rate: 0.0010
# Epoch 80/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - correlation_coefficient: 0.8950 - loss: 0.0659 - mae: 0.0614 - val_correlation_coefficient: 0.7070 - val_loss: 0.1467 - val_mae: 0.2787 - learning_rate: 0.0010
# Epoch 81/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - correlation_coefficient: 0.8944 - loss: 0.0680 - mae: 0.0711 - val_correlation_coefficient: 0.7078 - val_loss: 0.1042 - val_mae: 0.1915 - learning_rate: 0.0010
# Epoch 82/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - correlation_coefficient: 0.8942 - loss: 0.0647 - mae: 0.0564 - val_correlation_coefficient: 0.6888 - val_loss: 0.0682 - val_mae: 0.0837 - learning_rate: 0.0010
# Epoch 83/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - correlation_coefficient: 0.8961 - loss: 0.0618 - mae: 0.0510 - val_correlation_coefficient: 0.6629 - val_loss: 0.0681 - val_mae: 0.0834 - learning_rate: 0.0010
# Epoch 84/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - correlation_coefficient: 0.8938 - loss: 0.0649 - mae: 0.0687 - val_correlation_coefficient: 0.6642 - val_loss: 0.0649 - val_mae: 0.0749 - learning_rate: 0.0010
# Epoch 85/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - correlation_coefficient: 0.8922 - loss: 0.0655 - mae: 0.0693 - val_correlation_coefficient: 0.6842 - val_loss: 0.0699 - val_mae: 0.0987 - learning_rate: 0.0010
# Epoch 86/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - correlation_coefficient: 0.8957 - loss: 0.0598 - mae: 0.0478 - val_correlation_coefficient: 0.7080 - val_loss: 0.0877 - val_mae: 0.1552 - learning_rate: 0.0010
# Epoch 87/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - correlation_coefficient: 0.8936 - loss: 0.0610 - mae: 0.0584 - val_correlation_coefficient: 0.7206 - val_loss: 0.0985 - val_mae: 0.1872 - learning_rate: 0.0010
# Epoch 88/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - correlation_coefficient: 0.8955 - loss: 0.0596 - mae: 0.0534 - val_correlation_coefficient: 0.7195 - val_loss: 0.1215 - val_mae: 0.2412 - learning_rate: 0.0010
# Epoch 89/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - correlation_coefficient: 0.8918 - loss: 0.0656 - mae: 0.0839 - val_correlation_coefficient: 0.7004 - val_loss: 0.0804 - val_mae: 0.1364 - learning_rate: 0.0010
# Epoch 90/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - correlation_coefficient: 0.8924 - loss: 0.0632 - mae: 0.0795 - val_correlation_coefficient: 0.6890 - val_loss: 0.0724 - val_mae: 0.1138 - learning_rate: 0.0010
# Epoch 91/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - correlation_coefficient: 0.8947 - loss: 0.0581 - mae: 0.0593 - val_correlation_coefficient: 0.6885 - val_loss: 0.0802 - val_mae: 0.1392 - learning_rate: 0.0010
# Epoch 92/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - correlation_coefficient: 0.8929 - loss: 0.0583 - mae: 0.0517 - val_correlation_coefficient: 0.6873 - val_loss: 0.0844 - val_mae: 0.1546 - learning_rate: 0.0010
# Epoch 93/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - correlation_coefficient: 0.8935 - loss: 0.0582 - mae: 0.0636 - val_correlation_coefficient: 0.6955 - val_loss: 0.0911 - val_mae: 0.1758 - learning_rate: 0.0010
# Epoch 94/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - correlation_coefficient: 0.8942 - loss: 0.0564 - mae: 0.0536 - val_correlation_coefficient: 0.6920 - val_loss: 0.0821 - val_mae: 0.1502 - learning_rate: 0.0010
# Epoch 95/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - correlation_coefficient: 0.8956 - loss: 0.0544 - mae: 0.0440 - val_correlation_coefficient: 0.6930 - val_loss: 0.0834 - val_mae: 0.1554 - learning_rate: 5.0000e-04
# Epoch 96/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - correlation_coefficient: 0.8948 - loss: 0.0548 - mae: 0.0478 - val_correlation_coefficient: 0.6976 - val_loss: 0.0872 - val_mae: 0.1677 - learning_rate: 5.0000e-04
# Epoch 97/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - correlation_coefficient: 0.8937 - loss: 0.0550 - mae: 0.0559 - val_correlation_coefficient: 0.7066 - val_loss: 0.0881 - val_mae: 0.1711 - learning_rate: 5.0000e-04
# Epoch 98/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - correlation_coefficient: 0.8940 - loss: 0.0554 - mae: 0.0515 - val_correlation_coefficient: 0.7199 - val_loss: 0.0965 - val_mae: 0.1940 - learning_rate: 5.0000e-04
# Epoch 99/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - correlation_coefficient: 0.8937 - loss: 0.0554 - mae: 0.0551 - val_correlation_coefficient: 0.7375 - val_loss: 0.1201 - val_mae: 0.2468 - learning_rate: 5.0000e-04
# Epoch 100/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - correlation_coefficient: 0.8950 - loss: 0.0552 - mae: 0.0566 - val_correlation_coefficient: 0.7436 - val_loss: 0.1142 - val_mae: 0.2358 - learning_rate: 5.0000e-04
# Epoch 101/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8906 - loss: 0.0566 - mae: 0.0626 - val_correlation_coefficient: 0.7494 - val_loss: 0.1029 - val_mae: 0.2122 - learning_rate: 5.0000e-04
# Epoch 102/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8951 - loss: 0.0547 - mae: 0.0530 - val_correlation_coefficient: 0.7529 - val_loss: 0.0875 - val_mae: 0.1744 - learning_rate: 5.0000e-04
# Epoch 103/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - correlation_coefficient: 0.8964 - loss: 0.0516 - mae: 0.0452 - val_correlation_coefficient: 0.7567 - val_loss: 0.0799 - val_mae: 0.1528 - learning_rate: 5.0000e-04
# Epoch 104/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8966 - loss: 0.0516 - mae: 0.0433 - val_correlation_coefficient: 0.7606 - val_loss: 0.0784 - val_mae: 0.1487 - learning_rate: 5.0000e-04
# Epoch 105/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - correlation_coefficient: 0.8956 - loss: 0.0531 - mae: 0.0490 - val_correlation_coefficient: 0.7622 - val_loss: 0.0782 - val_mae: 0.1485 - learning_rate: 2.5000e-04
# Epoch 106/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8955 - loss: 0.0519 - mae: 0.0450 - val_correlation_coefficient: 0.7635 - val_loss: 0.0764 - val_mae: 0.1433 - learning_rate: 2.5000e-04
# Epoch 107/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8917 - loss: 0.0552 - mae: 0.0584 - val_correlation_coefficient: 0.7647 - val_loss: 0.0765 - val_mae: 0.1439 - learning_rate: 2.5000e-04
# Epoch 108/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - correlation_coefficient: 0.8919 - loss: 0.0560 - mae: 0.0630 - val_correlation_coefficient: 0.7674 - val_loss: 0.0862 - val_mae: 0.1737 - learning_rate: 2.5000e-04
# Epoch 109/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8929 - loss: 0.0532 - mae: 0.0499 - val_correlation_coefficient: 0.7712 - val_loss: 0.0970 - val_mae: 0.2018 - learning_rate: 2.5000e-04
# Epoch 110/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8918 - loss: 0.0543 - mae: 0.0612 - val_correlation_coefficient: 0.7741 - val_loss: 0.1020 - val_mae: 0.2138 - learning_rate: 2.5000e-04
# Epoch 111/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - correlation_coefficient: 0.8969 - loss: 0.0505 - mae: 0.0464 - val_correlation_coefficient: 0.7750 - val_loss: 0.0995 - val_mae: 0.2082 - learning_rate: 2.5000e-04
# Epoch 112/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8936 - loss: 0.0536 - mae: 0.0626 - val_correlation_coefficient: 0.7739 - val_loss: 0.0836 - val_mae: 0.1676 - learning_rate: 2.5000e-04
# Epoch 113/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8944 - loss: 0.0520 - mae: 0.0538 - val_correlation_coefficient: 0.7727 - val_loss: 0.0777 - val_mae: 0.1501 - learning_rate: 2.5000e-04
# Epoch 114/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - correlation_coefficient: 0.8941 - loss: 0.0517 - mae: 0.0523 - val_correlation_coefficient: 0.7710 - val_loss: 0.0721 - val_mae: 0.1329 - learning_rate: 2.5000e-04
# Epoch 115/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - correlation_coefficient: 0.8951 - loss: 0.0513 - mae: 0.0538 - val_correlation_coefficient: 0.7697 - val_loss: 0.0695 - val_mae: 0.1249 - learning_rate: 1.2500e-04
# Epoch 116/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8939 - loss: 0.0547 - mae: 0.0592 - val_correlation_coefficient: 0.7711 - val_loss: 0.0719 - val_mae: 0.1325 - learning_rate: 1.2500e-04
# Epoch 117/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - correlation_coefficient: 0.8942 - loss: 0.0518 - mae: 0.0564 - val_correlation_coefficient: 0.7724 - val_loss: 0.0743 - val_mae: 0.1399 - learning_rate: 1.2500e-04
# Epoch 118/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8946 - loss: 0.0510 - mae: 0.0547 - val_correlation_coefficient: 0.7725 - val_loss: 0.0753 - val_mae: 0.1435 - learning_rate: 1.2500e-04
# Epoch 119/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - correlation_coefficient: 0.8958 - loss: 0.0504 - mae: 0.0524 - val_correlation_coefficient: 0.7733 - val_loss: 0.0778 - val_mae: 0.1518 - learning_rate: 1.2500e-04
# Epoch 120/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - correlation_coefficient: 0.8960 - loss: 0.0497 - mae: 0.0433 - val_correlation_coefficient: 0.7740 - val_loss: 0.0800 - val_mae: 0.1589 - learning_rate: 1.2500e-04
# Epoch 121/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - correlation_coefficient: 0.8974 - loss: 0.0496 - mae: 0.0430 - val_correlation_coefficient: 0.7748 - val_loss: 0.0842 - val_mae: 0.1715 - learning_rate: 1.2500e-04
# Epoch 122/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - correlation_coefficient: 0.8972 - loss: 0.0485 - mae: 0.0355 - val_correlation_coefficient: 0.7747 - val_loss: 0.0861 - val_mae: 0.1768 - learning_rate: 1.2500e-04
# Epoch 123/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - correlation_coefficient: 0.8967 - loss: 0.0493 - mae: 0.0427 - val_correlation_coefficient: 0.7746 - val_loss: 0.0857 - val_mae: 0.1758 - learning_rate: 1.2500e-04
# Epoch 124/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - correlation_coefficient: 0.8949 - loss: 0.0520 - mae: 0.0554 - val_correlation_coefficient: 0.7751 - val_loss: 0.0898 - val_mae: 0.1867 - learning_rate: 1.2500e-04
# Epoch 125/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - correlation_coefficient: 0.8955 - loss: 0.0499 - mae: 0.0486 - val_correlation_coefficient: 0.7754 - val_loss: 0.0918 - val_mae: 0.1916 - learning_rate: 6.2500e-05
# Epoch 126/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - correlation_coefficient: 0.8920 - loss: 0.0535 - mae: 0.0592 - val_correlation_coefficient: 0.7755 - val_loss: 0.0892 - val_mae: 0.1852 - learning_rate: 6.2500e-05
# Epoch 127/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - correlation_coefficient: 0.8953 - loss: 0.0505 - mae: 0.0516 - val_correlation_coefficient: 0.7760 - val_loss: 0.0888 - val_mae: 0.1841 - learning_rate: 6.2500e-05
# Epoch 128/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - correlation_coefficient: 0.8934 - loss: 0.0515 - mae: 0.0544 - val_correlation_coefficient: 0.7767 - val_loss: 0.0894 - val_mae: 0.1857 - learning_rate: 6.2500e-05
# Epoch 129/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8960 - loss: 0.0493 - mae: 0.0424 - val_correlation_coefficient: 0.7772 - val_loss: 0.0907 - val_mae: 0.1892 - learning_rate: 6.2500e-05
# Epoch 130/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - correlation_coefficient: 0.8963 - loss: 0.0489 - mae: 0.0399 - val_correlation_coefficient: 0.7773 - val_loss: 0.0906 - val_mae: 0.1891 - learning_rate: 6.2500e-05
# Epoch 131/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - correlation_coefficient: 0.8927 - loss: 0.0524 - mae: 0.0545 - val_correlation_coefficient: 0.7771 - val_loss: 0.0904 - val_mae: 0.1887 - learning_rate: 6.2500e-05
# Epoch 132/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - correlation_coefficient: 0.8932 - loss: 0.0513 - mae: 0.0565 - val_correlation_coefficient: 0.7770 - val_loss: 0.0899 - val_mae: 0.1876 - learning_rate: 6.2500e-05
# Epoch 133/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - correlation_coefficient: 0.8928 - loss: 0.0514 - mae: 0.0571 - val_correlation_coefficient: 0.7771 - val_loss: 0.0889 - val_mae: 0.1851 - learning_rate: 6.2500e-05
# Epoch 134/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - correlation_coefficient: 0.8971 - loss: 0.0480 - mae: 0.0351 - val_correlation_coefficient: 0.7771 - val_loss: 0.0879 - val_mae: 0.1824 - learning_rate: 6.2500e-05
# Epoch 135/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - correlation_coefficient: 0.8935 - loss: 0.0521 - mae: 0.0624 - val_correlation_coefficient: 0.7770 - val_loss: 0.0865 - val_mae: 0.1788 - learning_rate: 3.1250e-05
# Epoch 136/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8940 - loss: 0.0519 - mae: 0.0518 - val_correlation_coefficient: 0.7770 - val_loss: 0.0860 - val_mae: 0.1775 - learning_rate: 3.1250e-05
# Epoch 137/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8956 - loss: 0.0494 - mae: 0.0473 - val_correlation_coefficient: 0.7771 - val_loss: 0.0860 - val_mae: 0.1773 - learning_rate: 3.1250e-05
# Epoch 138/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - correlation_coefficient: 0.8947 - loss: 0.0516 - mae: 0.0567 - val_correlation_coefficient: 0.7772 - val_loss: 0.0860 - val_mae: 0.1775 - learning_rate: 3.1250e-05
# Epoch 139/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - correlation_coefficient: 0.8951 - loss: 0.0498 - mae: 0.0517 - val_correlation_coefficient: 0.7771 - val_loss: 0.0858 - val_mae: 0.1769 - learning_rate: 3.1250e-05
# Epoch 140/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - correlation_coefficient: 0.8943 - loss: 0.0505 - mae: 0.0490 - val_correlation_coefficient: 0.7769 - val_loss: 0.0847 - val_mae: 0.1739 - learning_rate: 3.1250e-05
# Epoch 141/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8937 - loss: 0.0515 - mae: 0.0579 - val_correlation_coefficient: 0.7766 - val_loss: 0.0839 - val_mae: 0.1718 - learning_rate: 3.1250e-05
# Epoch 142/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8949 - loss: 0.0499 - mae: 0.0513 - val_correlation_coefficient: 0.7766 - val_loss: 0.0835 - val_mae: 0.1707 - learning_rate: 3.1250e-05
# Epoch 143/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8969 - loss: 0.0486 - mae: 0.0396 - val_correlation_coefficient: 0.7765 - val_loss: 0.0835 - val_mae: 0.1708 - learning_rate: 3.1250e-05
# Epoch 144/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8953 - loss: 0.0497 - mae: 0.0477 - val_correlation_coefficient: 0.7765 - val_loss: 0.0834 - val_mae: 0.1707 - learning_rate: 3.1250e-05
# Epoch 145/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - correlation_coefficient: 0.8933 - loss: 0.0507 - mae: 0.0499 - val_correlation_coefficient: 0.7765 - val_loss: 0.0834 - val_mae: 0.1706 - learning_rate: 1.5625e-05
# Epoch 146/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8957 - loss: 0.0496 - mae: 0.0467 - val_correlation_coefficient: 0.7766 - val_loss: 0.0837 - val_mae: 0.1715 - learning_rate: 1.5625e-05
# Epoch 147/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - correlation_coefficient: 0.8931 - loss: 0.0521 - mae: 0.0596 - val_correlation_coefficient: 0.7766 - val_loss: 0.0835 - val_mae: 0.1711 - learning_rate: 1.5625e-05
# Epoch 148/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - correlation_coefficient: 0.8942 - loss: 0.0512 - mae: 0.0555 - val_correlation_coefficient: 0.7766 - val_loss: 0.0836 - val_mae: 0.1713 - learning_rate: 1.5625e-05
# Epoch 149/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8934 - loss: 0.0513 - mae: 0.0580 - val_correlation_coefficient: 0.7766 - val_loss: 0.0831 - val_mae: 0.1700 - learning_rate: 1.5625e-05
# Epoch 150/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8958 - loss: 0.0489 - mae: 0.0405 - val_correlation_coefficient: 0.7766 - val_loss: 0.0828 - val_mae: 0.1690 - learning_rate: 1.5625e-05

# %%
# Evaluate the model
y_pred_scaled = model.predict(X_test_seq)
y_pred = target_scaler.inverse_transform(y_pred_scaled)
y_test_unscaled = target_scaler.inverse_transform(y_test_seq)

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

r2 = r2_score(y_test_unscaled, y_pred)
rmse = np.sqrt(mean_squared_error(y_test_unscaled, y_pred))
mae = mean_absolute_error(y_test_unscaled, y_pred)
rmae= np.sqrt(mean_absolute_error(y_test_unscaled, y_pred))
corr_coef = np.corrcoef(y_test_unscaled.flatten(), y_pred.flatten())[0,1]


residual_en = np.abs(y_test_unscaled-y_pred)
R2 = 1 - (residual_en/np.sum(np.sqrt(residual_en)))
np.average(R2)
print('R2 :'," ", np.average(R2))



print("\nTest Metrics:")
print('R2 :'," ", np.average(R2))
# print(f"R2: {r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"RMAE:{rmae:.4f}")

print(f"\nPrediction Range:")
print(f"Min: {y_pred.min():.4f}, Max: {y_pred.max():.4f}")

print(f"\nCorrelation coefficient: {corr_coef:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# R2 :   0.7956448662725177
#
# Test Metrics:
# R2 :   0.7956448662725177
# RMSE: 2.7670
# MAE: 2.4745
# RMAE:1.5731
#
# Prediction Range:
# Min: 24.2827, Max: 30.2349
#
# Correlation coefficient: 0.7773

# %%
y_test_unscaled
# Out:
# array([[30.755196],
#        [30.83819 ],
#        [30.633383],
#        [30.534817],
#        [30.59448 ],
#        [30.099432],
#        [26.97264 ],
#        [27.372815]])

# %%
y_pred
# Out:
# array([[30.234932],
#        [29.491333],
#        [28.731106],
#        [27.53249 ],
#        [26.293674],
#        [26.137793],
#        [25.300884],
#        [24.282694]], dtype=float32)

# %%
import seaborn as sns

# %%
# big2=df['Agricultural water share ']

# plt.figure(1)
# # plt.style.use('seaborn')
# plt.figure(figsize=(7,5))
# sns.set(font_scale=1.2)
# plt.plot(big2[:53],'--', color='black',markersize=12, linewidth=3)
# plt.plot(df[53:].index, y_test_unscaled,'-',color='orange',markersize=12, linewidth=3)
# plt.plot(df[53:].index,y_pred,'-', color='steelblue', markersize=12, linewidth=3)
# # plt.title('Measured against model data')
# plt.xlabel('Time (years)')
# plt.ylabel('Agricultural freshwater withdrawals (%)')
# # plt.legend(['Share of life Expectancy','Lasso Model prediction ' ])
# # plt.ylim(70, 80)
# plt.legend(['Ag. freshwater withdrawals (train set)','Ag. freshwater withdrawals(test set)','BiLSTM model prediction'  ])

# x = [ 0, 10,20,30,40,50,61]

# labels = [1961, 1970, 1980, 1990, 2000,2010, 2021]
# plt.xticks(x, labels, rotation='horizontal')
# # plt.savefig("Agricultural water_BiLSTM.png", dpi = 1000, bbox_inches='tight')

# %%
# big= df['GHGEs ']

# # plt.figure(1)
# # # plt.style.use('seaborn')
# plt.figure(figsize=(7,5))
# sns.set(font_scale=1.2)
# plt.plot(big[:53],'--', color='black',markersize=12, linewidth=2.5)
# plt.plot(df[53:].index, y_test_unscaled,'-',color='orange',markersize=12, linewidth=2.5)
# plt.plot(df[53:].index,y_pred,'-', color='steelblue', markersize=12, linewidth=2.5)
# # # plt.title('Measured against model data')
# plt.xlabel('Time (years)')
# plt.ylabel(r'GHGE, $CO_{2}$-eq')
# # # plt.legend(['Share of life Expectancy','Lasso Model prediction ' ])
# # # plt.ylim(70, 80)
# plt.legend(['GHGE (train set)', 'GHGE(test set)','BiLSTM model prediction'  ])

# x = [ 0, 10,20,30,40,50,61]

# labels = [1961, 1970, 1980, 1990, 2000,2010, 2021]
# plt.xticks(x, labels, rotation='horizontal')
# # plt.savefig("Surface temp. change_LSTM.png", dpi = 1000, bbox_inches='tight')

# %%
# big4= df[ 'Surface temp.']
# plt.figure(1)
# # plt.style.use('seaborn')
# plt.figure(figsize=(7,5))
# sns.set(font_scale=1.2)
# plt.plot(big4[:53],'--', color='black',markersize=12, linewidth=3)
# plt.plot(df[53:].index, y_test_unscaled,'-',color='orange',markersize=12, linewidth=3)
# plt.plot(df[53:].index,y_pred,'-', color='steelblue', markersize=12, linewidth=3)
# # plt.title('Measured against model data')
# plt.xlabel('Time (years)')
# plt.ylabel('Surface temp. change,\N{DEGREE SIGN}C')
# # # plt.ylim(5.5, 7)
# plt.legend(['Surface temp. change (train set)','Surface temp. change(test set)','BiLSTM model prediction'  ],fontsize= 12.5)

# x = [ 0, 10,20,30,40,50,61]

# labels = [1961, 1970, 1980, 1990, 2000,2010, 2021]
# plt.xticks(x, labels, rotation='horizontal')
# # plt.savefig("Agricultural water_BiLSTM.png", dpi = 1000, bbox_inches='tight')

# %%
# big3= df['Agricultural land use share ']
# plt.figure(1)
# # plt.style.use('seaborn')
# plt.figure(figsize=(7,5))
# sns.set(font_scale=1.2)
# plt.plot(big3[:53],'--', color='black',markersize=12, linewidth=3)
# plt.plot(df[53:].index, y_test_unscaled,'-',color='orange',markersize=12, linewidth=3)
# plt.plot(df[53:].index,y_pred,'-', color='steelblue', markersize=12, linewidth=3)
# # plt.title('Measured against model data')
# plt.xlabel('Time (years)')
# plt.ylabel('Agricultural land share(%)')
# # plt.legend(['Share of life Expectancy','Lasso Model prediction ' ])
# # plt.ylim(70, 80)
# plt.legend(['Ag. land share (train set)','Ag. land share (test set)','BiLSTM model prediction'  ])

# x = [ 0, 10,20,30,40,50,61]

# labels = [1961, 1970, 1980, 1990, 2000,2010, 2021]
# plt.xticks(x, labels, rotation='horizontal')
# # plt.savefig("Agricultural water_BiLSTM.png", dpi = 1000, bbox_inches='tight')

# %%
# Plot training & validation loss
# plt.style.use('seaborn')
# plt.figure(figsize=(7,5))
sns.set(font_scale=1.2)

plt.figure(figsize=(5,4))
plt.plot(history.history['loss'], label='Training Loss', linewidth=3, color='orange')
plt.plot(history.history['val_loss'], label='Validation Loss-BiLSTM', linewidth=3, color='steelblue')
# plt.title('Model Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.tight_layout()
# plt.savefig('Bidirection on GHGE_validation_loss.png', dpi = 1000, bbox_inches='tight')
plt.show()

# %%
# Plot training & validation MAE
# plt.style.use('seaborn')
# plt.figure(figsize=(7,5))
sns.set(font_scale=1.2)

plt.figure(figsize=(5,4))
plt.plot(history.history['mae'], label='Training MAE', linewidth=3, color='orange')
plt.plot(history.history['val_mae'], label='Validation MAE-BiLSTM', linewidth=3, color='steelblue')
# plt.title('Model MAE over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.tight_layout()
# plt.savefig('Bidirection on GHGE_MAE_loss.png', dpi = 1000, bbox_inches='tight')
plt.show()

# %% [markdown]
# GRAPHS FOR HEALTH INDICATORS

# %%
# bag1= df['Life expectancy ']
# plt.figure(1)
# # plt.style.use('seaborn')
# plt.figure(figsize=(7,5))
# sns.set(font_scale=1.2)
# plt.plot(bag1[:53],'--', color='black',markersize=12, linewidth=3)
# plt.plot(df[53:].index, y_test_unscaled,'-',color='orange',markersize=12, linewidth=3)
# plt.plot(df[53:].index,y_pred,'-', color='steelblue', markersize=12, linewidth=3)
# # plt.title('Measured against model data')
# plt.xlabel('Time (years)')
# plt.ylabel('Life expectancy, yrs ')

# # plt.ylim(70, 80)
# plt.legend(['Life expectancy(train set)', 'Life expectancy(test set)','BiLSTM model prediction'  ])

# x = [ 0, 10,20,30,40,50,61]

# labels = [1961, 1970, 1980, 1990, 2000,2010, 2021]
# plt.xticks(x, labels, rotation='horizontal')
# # plt.savefig("Agricultural water_BiLSTM.png", dpi = 1000, bbox_inches='tight')

# %%
# bag2= df['Obese']
# plt.figure(1)
# # plt.style.use('seaborn')
# plt.figure(figsize=(7,5))
# sns.set(font_scale=1.2)
# plt.plot(bag2[:53],'--', color='black',markersize=12, linewidth=3)
# plt.plot(df[53:].index, y_test_unscaled,'-',color='orange',markersize=12, linewidth=3)
# plt.plot(df[53:].index,y_pred,'-', color='steelblue', markersize=12, linewidth=3)
# # plt.title('Measured against model data')
# plt.xlabel('Time (years)')
# plt.ylabel('Share of obesity, % ')
# # plt.legend(['Share of life Expectancy','Lasso Model prediction ' ])
# # plt.ylim(70, 80)
# plt.legend(['Share of obesity(train set)', 'Share of obesity(test set)','BiLSTM model prediction'  ])


# x = [ 0, 10,20,30,40,50,61]

# labels = [1961, 1970, 1980, 1990, 2000,2010, 2021]
# plt.xticks(x, labels, rotation='horizontal')
# # plt.savefig("Agricultural water_BiLSTM.png", dpi = 1000, bbox_inches='tight')

# %%
bag3= df['Death-NCD ']
plt.figure(1)
# plt.style.use('seaborn')
plt.figure(figsize=(7,5))
sns.set(font_scale=1.2)
plt.plot(bag3[:53],'--', color='black',markersize=12, linewidth=3)
plt.plot(df[53:].index, y_test_unscaled,'-',color='orange',markersize=12, linewidth=3)
plt.plot(df[53:].index,y_pred,'-', color='steelblue', markersize=12, linewidth=3)
# plt.title('Measured against model data')
plt.xlabel('Time (years)')
plt.ylabel('Share of death due CVD, % ')
# plt.legend(['Share of life Expectancy','Lasso Model prediction ' ])
# plt.ylim(70, 80)
plt.legend(['Share of death due CVD(train set)', 'Share of death due CVD(test set)','BiLSTM model prediction'  ])


x = [ 0, 10,20,30,40,50,61]

labels = [1961, 1970, 1980, 1990, 2000,2010, 2021]
plt.xticks(x, labels, rotation='horizontal')
# plt.savefig("Agricultural water_BiLSTM.png", dpi = 1000, bbox_inches='tight')
# Out:
# ([<matplotlib.axis.XTick at 0x7ea82ddc6f20>,
#   <matplotlib.axis.XTick at 0x7ea82ddc5930>,
#   <matplotlib.axis.XTick at 0x7ea82d0970a0>,
#   <matplotlib.axis.XTick at 0x7ea82de26da0>,
#   <matplotlib.axis.XTick at 0x7ea84a7744c0>,
#   <matplotlib.axis.XTick at 0x7ea82ddc6b60>,
#   <matplotlib.axis.XTick at 0x7ea82ddc7640>],
#  [Text(0, 0, '1961'),
#   Text(10, 0, '1970'),
#   Text(20, 0, '1980'),
#   Text(30, 0, '1990'),
#   Text(40, 0, '2000'),
#   Text(50, 0, '2010'),
#   Text(61, 0, '2021')])
