# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import joblib
import os
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
import random
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
# ---------------------------
# 1. Load and Preprocess Data
# ---------------------------

# Load data
df = pd.read_excel('Data_GHGE.xlsx')

# Feature selection
feature_columns = [
    'FP index ', 'LP index ', 'Vegetal Pds-FS', 'Cereals -FS', 'Starchy Rts-FS',
    'Pulses-FS', 'Fruits -FS', 'Meat-FS', 'Fish-FS', 'Sugar & Swt-FS', 
    'Oils-FS ', 'Vegetables-FS ', 'Spices-FS', 'Eggs-FS', 'Milk-FS',
    'Cereals-LSF', 'Starchy Rts-LSF', 'Pulses-LSF', 'Meat-LSF', 'Fish-LSF',
    'Cereals-LS', 'Starchy-LS', 'Fruits-LS', 'Energy use', 'Renewable energy '
]

df.columns
# Out:
# Index(['Indicator Code', 'FP index ', 'LP index ', 'Vegetal Pds-FS',
#        'Cereals -FS', 'Starchy Rts-FS', 'Pulses-FS', 'Fruits -FS', 'Meat-FS',
#        'Fish-FS', 'Sugar & Swt-FS', 'Oils-FS ', 'Vegetables-FS ', 'Spices-FS',
#        'Eggs-FS', 'Milk-FS', 'Cereals-LSF', 'Starchy Rts-LSF', 'Pulses-LSF',
#        'Meat-LSF', 'Fish-LSF', 'Cereals-LS', 'Starchy-LS', 'Fruits-LS',
#        'Energy use', 'Renewable energy ', 'GHGEs ',
#        'Agricultural land use share ', 'Agricultural water share ',
#        'Surface temp.', 'Overweight', 'Obese', 'Death-NCD ',
#        'Life expectancy '],
#       dtype='object')

# %%
X = df[feature_columns].values
y = df[ 'Life expectancy '].values 

# Split data before scaling to prevent data leakage
X_train_raw, X_test_raw, y_train_raw, y_test_raw = train_test_split(
    X, y, test_size=0.15, random_state=42,
    stratify=pd.qcut(y, q=5, labels=False)
)


# Initialize scalers
feature_scaler = RobustScaler()
target_scaler = RobustScaler()

# %%
# Fit scalers on training data
X_train_scaled = feature_scaler.fit_transform(X_train_raw)
y_train_scaled = target_scaler.fit_transform(y_train_raw.reshape(-1, 1))

# Transform test data
X_test_scaled = feature_scaler.transform(X_test_raw)
y_test_scaled = target_scaler.transform(y_test_raw.reshape(-1, 1))

# Create sequences
def create_sequences(X, y, sequence_length=3):
    sequences_X = []
    sequences_y = []
    for i in range(len(X) - sequence_length + 1):
        sequences_X.append(X[i:i+sequence_length])
        sequences_y.append(y[i+sequence_length-1])
    return np.array(sequences_X), np.array(sequences_y)

# Create sequences in training data
X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_scaled, sequence_length=3)

# Create sequences in test data
X_test_seq, y_test_seq = create_sequences(X_test_scaled, y_test_scaled, sequence_length=3)

# %%
# 2. Build the Bidirectional LSTM Model
# ---------------------------

from tensorflow.keras.layers import Bidirectional

# Build the model
model = Sequential([
    LSTM(100, input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]), return_sequences=True, 
         kernel_regularizer=l2(0.001)),
    Dropout(0.3),
    
    LSTM(100, return_sequences=False, kernel_regularizer=l2(0.001)),
    Dropout(0.3),
    
    Dense(16, activation='relu', kernel_regularizer=l2(0.001)),
    Dense(1, activation='linear')
])
# Out:
# C:\Users\Prince\Anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#  Define custom metric
def correlation_coefficient(y_true, y_pred):
    x = y_true - K.mean(y_true)
    y = y_pred - K.mean(y_pred)
    numerator = K.sum(x * y)
    denominator = K.sqrt(K.sum(K.square(x)) * K.sum(K.square(y)))
    return numerator / (denominator + K.epsilon())

# Compile the model
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mean_squared_error',
    metrics=['mae', correlation_coefficient]
)

# %%
# 4. Train the Model
# ---------------------------

# Callbacks
callbacks = [
    EarlyStopping(monitor='val_correlation_coefficient', mode='max', patience=20, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-5)
]

# Train the model
history = model.fit(
    X_train_seq, y_train_seq,
    validation_data=(X_test_seq, y_test_seq),
    epochs=200,
    batch_size=16,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - correlation_coefficient: -0.0326 - loss: 0.6398 - mae: 0.5407 - val_correlation_coefficient: 0.4639 - val_loss: 0.5931 - val_mae: 0.4996 - learning_rate: 0.0010
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - correlation_coefficient: 0.0943 - loss: 0.6160 - mae: 0.5347 - val_correlation_coefficient: 0.5899 - val_loss: 0.5720 - val_mae: 0.4946 - learning_rate: 0.0010
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - correlation_coefficient: 0.4391 - loss: 0.5845 - mae: 0.5259 - val_correlation_coefficient: 0.6320 - val_loss: 0.5498 - val_mae: 0.4853 - learning_rate: 0.0010
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - correlation_coefficient: 0.4467 - loss: 0.5729 - mae: 0.5265 - val_correlation_coefficient: 0.7044 - val_loss: 0.5272 - val_mae: 0.4760 - learning_rate: 0.0010
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.5226 - loss: 0.5556 - mae: 0.5176 - val_correlation_coefficient: 0.7419 - val_loss: 0.5065 - val_mae: 0.4693 - learning_rate: 0.0010
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.5176 - loss: 0.5376 - mae: 0.5175 - val_correlation_coefficient: 0.7347 - val_loss: 0.4870 - val_mae: 0.4615 - learning_rate: 0.0010
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.6394 - loss: 0.5004 - mae: 0.4972 - val_correlation_coefficient: 0.6826 - val_loss: 0.4692 - val_mae: 0.4517 - learning_rate: 0.0010
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.6380 - loss: 0.4828 - mae: 0.4876 - val_correlation_coefficient: 0.6303 - val_loss: 0.4534 - val_mae: 0.4411 - learning_rate: 0.0010
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.6631 - loss: 0.4462 - mae: 0.4677 - val_correlation_coefficient: 0.6241 - val_loss: 0.4319 - val_mae: 0.4321 - learning_rate: 0.0010
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.6698 - loss: 0.4202 - mae: 0.4528 - val_correlation_coefficient: 0.6377 - val_loss: 0.4109 - val_mae: 0.4275 - learning_rate: 0.0010
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.6030 - loss: 0.4079 - mae: 0.4490 - val_correlation_coefficient: 0.6475 - val_loss: 0.4016 - val_mae: 0.4308 - learning_rate: 0.0010
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.6524 - loss: 0.3609 - mae: 0.4109 - val_correlation_coefficient: 0.6563 - val_loss: 0.3955 - val_mae: 0.4217 - learning_rate: 0.0010
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.7245 - loss: 0.3122 - mae: 0.3589 - val_correlation_coefficient: 0.6693 - val_loss: 0.3746 - val_mae: 0.3945 - learning_rate: 0.0010
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.7187 - loss: 0.2884 - mae: 0.3311 - val_correlation_coefficient: 0.6841 - val_loss: 0.3432 - val_mae: 0.3672 - learning_rate: 0.0010
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.7680 - loss: 0.2425 - mae: 0.2891 - val_correlation_coefficient: 0.7145 - val_loss: 0.3132 - val_mae: 0.3417 - learning_rate: 0.0010
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.7913 - loss: 0.2196 - mae: 0.2688 - val_correlation_coefficient: 0.7422 - val_loss: 0.2910 - val_mae: 0.3396 - learning_rate: 0.0010
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.7886 - loss: 0.2173 - mae: 0.2482 - val_correlation_coefficient: 0.7745 - val_loss: 0.2689 - val_mae: 0.3271 - learning_rate: 0.0010
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8352 - loss: 0.1743 - mae: 0.1832 - val_correlation_coefficient: 0.8062 - val_loss: 0.2466 - val_mae: 0.3125 - learning_rate: 0.0010
# Epoch 19/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8431 - loss: 0.1688 - mae: 0.1998 - val_correlation_coefficient: 0.8322 - val_loss: 0.2279 - val_mae: 0.2981 - learning_rate: 0.0010
# Epoch 20/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8548 - loss: 0.1539 - mae: 0.1663 - val_correlation_coefficient: 0.8526 - val_loss: 0.2122 - val_mae: 0.2763 - learning_rate: 0.0010
# Epoch 21/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - correlation_coefficient: 0.8559 - loss: 0.1527 - mae: 0.1595 - val_correlation_coefficient: 0.8743 - val_loss: 0.1969 - val_mae: 0.2484 - learning_rate: 0.0010
# Epoch 22/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8627 - loss: 0.1480 - mae: 0.1645 - val_correlation_coefficient: 0.8919 - val_loss: 0.1845 - val_mae: 0.2260 - learning_rate: 0.0010
# Epoch 23/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8764 - loss: 0.1304 - mae: 0.1324 - val_correlation_coefficient: 0.9075 - val_loss: 0.1734 - val_mae: 0.2044 - learning_rate: 0.0010
# Epoch 24/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - correlation_coefficient: 0.8531 - loss: 0.1489 - mae: 0.1771 - val_correlation_coefficient: 0.9208 - val_loss: 0.1626 - val_mae: 0.1868 - learning_rate: 0.0010
# Epoch 25/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8683 - loss: 0.1299 - mae: 0.1371 - val_correlation_coefficient: 0.9302 - val_loss: 0.1535 - val_mae: 0.1766 - learning_rate: 0.0010
# Epoch 26/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8600 - loss: 0.1393 - mae: 0.1603 - val_correlation_coefficient: 0.9377 - val_loss: 0.1471 - val_mae: 0.1732 - learning_rate: 0.0010
# Epoch 27/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8579 - loss: 0.1350 - mae: 0.1620 - val_correlation_coefficient: 0.9368 - val_loss: 0.1460 - val_mae: 0.1769 - learning_rate: 0.0010
# Epoch 28/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8687 - loss: 0.1216 - mae: 0.1406 - val_correlation_coefficient: 0.9314 - val_loss: 0.1462 - val_mae: 0.1820 - learning_rate: 0.0010
# Epoch 29/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - correlation_coefficient: 0.8655 - loss: 0.1262 - mae: 0.1345 - val_correlation_coefficient: 0.9277 - val_loss: 0.1442 - val_mae: 0.1831 - learning_rate: 0.0010
# Epoch 30/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8777 - loss: 0.1154 - mae: 0.1258 - val_correlation_coefficient: 0.9259 - val_loss: 0.1434 - val_mae: 0.1985 - learning_rate: 0.0010
# Epoch 31/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8655 - loss: 0.1213 - mae: 0.1447 - val_correlation_coefficient: 0.9303 - val_loss: 0.1397 - val_mae: 0.1997 - learning_rate: 0.0010
# Epoch 32/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8743 - loss: 0.1125 - mae: 0.1251 - val_correlation_coefficient: 0.9358 - val_loss: 0.1367 - val_mae: 0.1971 - learning_rate: 0.0010
# Epoch 33/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8810 - loss: 0.1076 - mae: 0.1101 - val_correlation_coefficient: 0.9408 - val_loss: 0.1314 - val_mae: 0.1863 - learning_rate: 0.0010
# Epoch 34/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8736 - loss: 0.1121 - mae: 0.1352 - val_correlation_coefficient: 0.9480 - val_loss: 0.1220 - val_mae: 0.1618 - learning_rate: 0.0010
# Epoch 35/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8784 - loss: 0.1047 - mae: 0.1079 - val_correlation_coefficient: 0.9507 - val_loss: 0.1198 - val_mae: 0.1496 - learning_rate: 0.0010
# Epoch 36/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8849 - loss: 0.1001 - mae: 0.1090 - val_correlation_coefficient: 0.9532 - val_loss: 0.1175 - val_mae: 0.1472 - learning_rate: 0.0010
# Epoch 37/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8778 - loss: 0.1053 - mae: 0.1248 - val_correlation_coefficient: 0.9528 - val_loss: 0.1161 - val_mae: 0.1450 - learning_rate: 0.0010
# Epoch 38/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8769 - loss: 0.1018 - mae: 0.1157 - val_correlation_coefficient: 0.9511 - val_loss: 0.1168 - val_mae: 0.1511 - learning_rate: 0.0010
# Epoch 39/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8727 - loss: 0.1052 - mae: 0.1263 - val_correlation_coefficient: 0.9474 - val_loss: 0.1173 - val_mae: 0.1555 - learning_rate: 0.0010
# Epoch 40/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8856 - loss: 0.0923 - mae: 0.0949 - val_correlation_coefficient: 0.9439 - val_loss: 0.1180 - val_mae: 0.1687 - learning_rate: 0.0010
# Epoch 41/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8826 - loss: 0.0955 - mae: 0.1080 - val_correlation_coefficient: 0.9428 - val_loss: 0.1178 - val_mae: 0.1751 - learning_rate: 0.0010
# Epoch 42/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8857 - loss: 0.0917 - mae: 0.1074 - val_correlation_coefficient: 0.9465 - val_loss: 0.1145 - val_mae: 0.1712 - learning_rate: 0.0010
# Epoch 43/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8831 - loss: 0.0916 - mae: 0.0961 - val_correlation_coefficient: 0.9488 - val_loss: 0.1118 - val_mae: 0.1647 - learning_rate: 0.0010
# Epoch 44/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8873 - loss: 0.0861 - mae: 0.0864 - val_correlation_coefficient: 0.9513 - val_loss: 0.1091 - val_mae: 0.1582 - learning_rate: 0.0010
# Epoch 45/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8787 - loss: 0.0936 - mae: 0.1076 - val_correlation_coefficient: 0.9533 - val_loss: 0.1070 - val_mae: 0.1535 - learning_rate: 0.0010
# Epoch 46/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8844 - loss: 0.0884 - mae: 0.1008 - val_correlation_coefficient: 0.9533 - val_loss: 0.1060 - val_mae: 0.1514 - learning_rate: 0.0010
# Epoch 47/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - correlation_coefficient: 0.8832 - loss: 0.0882 - mae: 0.1037 - val_correlation_coefficient: 0.9543 - val_loss: 0.1041 - val_mae: 0.1508 - learning_rate: 0.0010
# Epoch 48/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8809 - loss: 0.0880 - mae: 0.1062 - val_correlation_coefficient: 0.9543 - val_loss: 0.1042 - val_mae: 0.1541 - learning_rate: 0.0010
# Epoch 49/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8789 - loss: 0.0928 - mae: 0.1233 - val_correlation_coefficient: 0.9576 - val_loss: 0.1009 - val_mae: 0.1465 - learning_rate: 0.0010
# Epoch 50/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - correlation_coefficient: 0.8873 - loss: 0.0861 - mae: 0.1079 - val_correlation_coefficient: 0.9610 - val_loss: 0.0970 - val_mae: 0.1418 - learning_rate: 0.0010
# Epoch 51/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8869 - loss: 0.0819 - mae: 0.0872 - val_correlation_coefficient: 0.9624 - val_loss: 0.0954 - val_mae: 0.1367 - learning_rate: 0.0010
# Epoch 52/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8841 - loss: 0.0827 - mae: 0.1024 - val_correlation_coefficient: 0.9610 - val_loss: 0.0956 - val_mae: 0.1385 - learning_rate: 0.0010
# Epoch 53/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8848 - loss: 0.0807 - mae: 0.1000 - val_correlation_coefficient: 0.9612 - val_loss: 0.0953 - val_mae: 0.1372 - learning_rate: 0.0010
# Epoch 54/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8905 - loss: 0.0764 - mae: 0.0813 - val_correlation_coefficient: 0.9635 - val_loss: 0.0940 - val_mae: 0.1363 - learning_rate: 0.0010
# Epoch 55/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8785 - loss: 0.0860 - mae: 0.1154 - val_correlation_coefficient: 0.9675 - val_loss: 0.0901 - val_mae: 0.1266 - learning_rate: 0.0010
# Epoch 56/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - correlation_coefficient: 0.8858 - loss: 0.0775 - mae: 0.0942 - val_correlation_coefficient: 0.9687 - val_loss: 0.0872 - val_mae: 0.1291 - learning_rate: 0.0010
# Epoch 57/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - correlation_coefficient: 0.8917 - loss: 0.0716 - mae: 0.0711 - val_correlation_coefficient: 0.9686 - val_loss: 0.0864 - val_mae: 0.1335 - learning_rate: 0.0010
# Epoch 58/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.
# Epoch 199/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8952 - loss: 0.0253 - mae: 0.0543 - val_correlation_coefficient: 0.9889 - val_loss: 0.0295 - val_mae: 0.0811 - learning_rate: 0.0010
# Epoch 200/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8943 - loss: 0.0253 - mae: 0.0597 - val_correlation_coefficient: 0.9904 - val_loss: 0.0286 - val_mae: 0.0755 - learning_rate: 0.0010

# %%
# Evaluate the model
y_pred_scaled = model.predict(X_test_seq)
y_pred = target_scaler.inverse_transform(y_pred_scaled)
y_test_unscaled = target_scaler.inverse_transform(y_test_seq)

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

r2 = r2_score(y_test_unscaled, y_pred)
rmse = np.sqrt(mean_squared_error(y_test_unscaled, y_pred))
mae = mean_absolute_error(y_test_unscaled, y_pred)
rmae= np.sqrt(mean_absolute_error(y_test_unscaled, y_pred))
corr_coef = np.corrcoef(y_test_unscaled.flatten(), y_pred.flatten())[0,1]

print("\nTest Metrics:")
print(f"R2: {r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"RMAE:{rmae:.4f}")

print(f"\nPrediction Range:")
print(f"Min: {y_pred.min():.4f}, Max: {y_pred.max():.4f}")

print(f"\nCorrelation coefficient: {corr_coef:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
#
# Test Metrics:
# R2: 0.9777
# RMSE: 0.4386
# MAE: 0.3356
# RMAE:0.5793
#
# Prediction Range:
# Min: 70.4495, Max: 78.1236
#
# Correlation coefficient: 0.9936

# %% [markdown]
# # Training and validation loss

# %%
# Plot training & validation loss
plt.figure(figsize=(8,6))
plt.plot(history.history['loss'], label='Training Loss', linewidth=3)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=3)
plt.title('Model Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.tight_layout()
# plt.savefig('figures/training_validation_loss.png')
plt.show()

# %%
# Plot training & validation MAE
plt.figure(figsize=(8,6))
plt.plot(history.history['mae'], label='Training MAE', linewidth=3)
plt.plot(history.history['val_mae'], label='Validation MAE', linewidth=3)
plt.title('Model MAE over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.tight_layout()
# plt.savefig('figures/training_validation_mae.png')
plt.show()

# %%
# 8. Additional Visualizations
# ---------------------------

# Feature Importance using Permutation Importance (Optional)
from sklearn.inspection import permutation_importance

# Since LSTM models are not directly compatible with permutation importance,
# we'll use a simple approximation by training a Random Forest as a surrogate model.

from sklearn.ensemble import RandomForestRegressor

# Train a Random Forest on the scaled training data
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train_scaled, y_train_scaled.ravel())

# Compute permutation importance on the test data
perm_importance = permutation_importance(rf, X_test_scaled, y_test_scaled.ravel(), n_repeats=10, random_state=42)

# Get feature importances
feature_importances = perm_importance.importances_mean

# Plot Feature Importances
sorted_idx = feature_importances.argsort()
plt.figure(figsize=(8,6))
plt.barh(range(len(sorted_idx)), feature_importances[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), np.array(feature_columns)[sorted_idx])
plt.title('Feature Importances from Random Forest')
plt.xlabel('Mean Decrease in Impurity')
plt.tight_layout()
# plt.savefig('figures/feature_importances.png')
plt.show()

# Save the feature importances to a CSV file
feature_importance_df = pd.DataFrame({
    'Feature': np.array(feature_columns)[sorted_idx],
    'Importance': feature_importances[sorted_idx]
})
# feature_importance_df.to_csv('figures/feature_importances.csv', index=False)

# %%
# # Save the scalers
# os.makedirs('models', exist_ok=True)
# joblib.dump(feature_scaler, 'scaler.pkl')
# joblib.dump(target_scaler, 'models/target_scaler.save')

# # Save the model
# model.save('models/lstm_life_expectancy.h5')

# %% [markdown]
# # Importing the saved model for prediction
