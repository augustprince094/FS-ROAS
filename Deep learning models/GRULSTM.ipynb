# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import joblib
import os
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
import random
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# ---------------------------
# 1. Load and Preprocess Data
# ---------------------------

# Load data
# Use pd.read_excel() since the file is an Excel file (.xlsx)
df = pd.read_excel("/content/Data_GHGE.xlsx")

# Feature selection
feature_columns = [
   'FP index ', 'LP index ', 'Vegetal Pds-FS', 'Cereals -FS',
       'Starchy Rts-FS', 'Pulses-FS', 'Fruits -FS', 'Meat-FS', 'Fish-FS',
       'Sugar & Swt-FS', 'Oils-FS ', 'Vegetables-FS ', 'Spices-FS', 'Eggs-FS',
       'Milk-FS', 'Cereals-LSF', 'Starchy Rts-LSF', 'Pulses-LSF', 'Meat-LSF',
       'Fish-LSF', 'Cereals-LS', 'Starchy-LS', 'Fruits-LS', 'Energy use',
       'Renewable energy '
]

# %%
df.columns
# Out:
# Index(['Indicator Code', 'FP index ', 'LP index ', 'Vegetal Pds-FS',
#        'Cereals -FS', 'Starchy Rts-FS', 'Pulses-FS', 'Fruits -FS', 'Meat-FS',
#        'Fish-FS', 'Sugar & Swt-FS', 'Oils-FS ', 'Vegetables-FS ', 'Spices-FS',
#        'Eggs-FS', 'Milk-FS', 'Cereals-LSF', 'Starchy Rts-LSF', 'Pulses-LSF',
#        'Meat-LSF', 'Fish-LSF', 'Cereals-LS', 'Starchy-LS', 'Fruits-LS',
#        'Energy use', 'Renewable energy ', 'GHGEs ',
#        'Agricultural land use share ', 'Agricultural water share ',
#        'Surface temp.', 'Overweight', 'Obese', 'Death-NCD ',
#        'Life expectancy '],
#       dtype='object')

# %%
X = df[feature_columns].values
y = df['Surface temp.'].values

# Split data before scaling to prevent data leakage


X_train_raw= X[:51]
X_test_raw = X[51:]
y_train_raw= y[:51]
y_test_raw= y[51:]



# x_train = X_x[:52]
# x_test = X_x[52:]
# y_train = Y_data[:52]
# y_test = Y_data[52:]






# Initialize scalers
feature_scaler = RobustScaler()
target_scaler = RobustScaler()
from sklearn.preprocessing import StandardScaler
# feature_scaler = StandardScaler()
# target_scaler = StandardScaler()

# %%
y_test_raw
# Out:
# array([0.06064492, 0.06065208, 0.06066183, 0.06067276, 0.06070957,
#        0.06076996, 0.060842  , 0.06092494, 0.06102614, 0.06112592])

# %%
# Fit scalers on training data
X_train_scaled = feature_scaler.fit_transform(X_train_raw)
y_train_scaled = target_scaler.fit_transform(y_train_raw.reshape(-1, 1))

# Transform test data
X_test_scaled = feature_scaler.transform(X_test_raw)
y_test_scaled = target_scaler.transform(y_test_raw.reshape(-1, 1))

# Create sequences
def create_sequences(X, y, sequence_length=3):
    sequences_X = []
    sequences_y = []
    for i in range(len(X) - sequence_length + 1):
        sequences_X.append(X[i:i+sequence_length])
        sequences_y.append(y[i+sequence_length-1])
    return np.array(sequences_X), np.array(sequences_y)

# Create sequences in training data
X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_scaled, sequence_length=3)

# Create sequences in test data
X_test_seq, y_test_seq = create_sequences(X_test_scaled, y_test_scaled, sequence_length=3)

# %%
# 2. Build the Bidirectional LSTM Model
# ---------------------------

from tensorflow.keras.layers import Bidirectional

# Build the model
model = Sequential([
    GRU(64, input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]), return_sequences=True,
         kernel_regularizer=l2(0.001)),
    Dropout(0.3),

    GRU(32, return_sequences=False, kernel_regularizer=l2(0.001)),
    Dropout(0.3),

    Dense(16, activation='relu', kernel_regularizer=l2(0.001)),
    Dense(1, activation='linear')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#  Define custom metric
def correlation_coefficient(y_true, y_pred):
    x = y_true - K.mean(y_true)
    y = y_pred - K.mean(y_pred)
    numerator = K.sum(x * y)
    denominator = K.sqrt(K.sum(K.square(x)) * K.sum(K.square(y)))
    return numerator / (denominator + K.epsilon())

# Compile the model
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mean_squared_error',
    metrics=['mae', correlation_coefficient]
)

# %%
# 4. Train the Model
# ---------------------------

# Callbacks
callbacks = [
    EarlyStopping(monitor='val_correlation_coefficient', mode='max', patience=20, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-5)
]

# Train the model
history = model.fit(
    X_train_seq, y_train_seq,
    validation_data=(X_test_seq, y_test_seq),
    epochs=700,
    batch_size=16,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 175ms/step - correlation_coefficient: -0.0453 - loss: 1.0715 - mae: 0.5636 - val_correlation_coefficient: -0.9856 - val_loss: 0.5046 - val_mae: 0.5605 - learning_rate: 0.0010
# Epoch 2/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.3939 - loss: 0.9392 - mae: 0.5170 - val_correlation_coefficient: -0.9776 - val_loss: 0.5134 - val_mae: 0.5715 - learning_rate: 0.0010
# Epoch 3/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - correlation_coefficient: 0.4021 - loss: 0.9215 - mae: 0.5240 - val_correlation_coefficient: -0.9714 - val_loss: 0.5103 - val_mae: 0.5706 - learning_rate: 0.0010
# Epoch 4/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - correlation_coefficient: 0.5666 - loss: 0.8516 - mae: 0.4900 - val_correlation_coefficient: -0.9643 - val_loss: 0.5095 - val_mae: 0.5710 - learning_rate: 0.0010
# Epoch 5/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.6660 - loss: 0.7710 - mae: 0.4612 - val_correlation_coefficient: -0.9579 - val_loss: 0.5123 - val_mae: 0.5735 - learning_rate: 0.0010
# Epoch 6/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.7345 - loss: 0.6625 - mae: 0.4187 - val_correlation_coefficient: -0.9504 - val_loss: 0.5136 - val_mae: 0.5719 - learning_rate: 0.0010
# Epoch 7/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.7766 - loss: 0.5643 - mae: 0.3899 - val_correlation_coefficient: -0.9410 - val_loss: 0.5106 - val_mae: 0.5655 - learning_rate: 0.0010
# Epoch 8/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8128 - loss: 0.4265 - mae: 0.3271 - val_correlation_coefficient: -0.9312 - val_loss: 0.5100 - val_mae: 0.5601 - learning_rate: 0.0010
# Epoch 9/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - correlation_coefficient: 0.7942 - loss: 0.3370 - mae: 0.2710 - val_correlation_coefficient: -0.9228 - val_loss: 0.5185 - val_mae: 0.5624 - learning_rate: 0.0010
# Epoch 10/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8111 - loss: 0.3295 - mae: 0.2842 - val_correlation_coefficient: -0.9157 - val_loss: 0.5224 - val_mae: 0.5600 - learning_rate: 0.0010
# Epoch 11/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.7897 - loss: 0.2759 - mae: 0.2592 - val_correlation_coefficient: -0.9104 - val_loss: 0.5371 - val_mae: 0.5683 - learning_rate: 0.0010
# Epoch 12/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8272 - loss: 0.2240 - mae: 0.2117 - val_correlation_coefficient: -0.9090 - val_loss: 0.5493 - val_mae: 0.5778 - learning_rate: 5.0000e-04
# Epoch 13/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - correlation_coefficient: 0.8162 - loss: 0.2744 - mae: 0.2674 - val_correlation_coefficient: -0.9082 - val_loss: 0.5577 - val_mae: 0.5845 - learning_rate: 5.0000e-04
# Epoch 14/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.7922 - loss: 0.2414 - mae: 0.2286 - val_correlation_coefficient: -0.9077 - val_loss: 0.5676 - val_mae: 0.5935 - learning_rate: 5.0000e-04
# Epoch 15/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - correlation_coefficient: 0.8318 - loss: 0.2304 - mae: 0.2195 - val_correlation_coefficient: -0.9068 - val_loss: 0.5790 - val_mae: 0.6030 - learning_rate: 5.0000e-04
# Epoch 16/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8104 - loss: 0.2432 - mae: 0.2514 - val_correlation_coefficient: -0.9040 - val_loss: 0.5810 - val_mae: 0.6037 - learning_rate: 5.0000e-04
# Epoch 17/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.8484 - loss: 0.1976 - mae: 0.1995 - val_correlation_coefficient: -0.9006 - val_loss: 0.5868 - val_mae: 0.6083 - learning_rate: 5.0000e-04
# Epoch 18/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.8150 - loss: 0.2396 - mae: 0.2454 - val_correlation_coefficient: -0.8969 - val_loss: 0.5964 - val_mae: 0.6162 - learning_rate: 5.0000e-04
# Epoch 19/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8495 - loss: 0.1977 - mae: 0.1827 - val_correlation_coefficient: -0.8934 - val_loss: 0.6090 - val_mae: 0.6270 - learning_rate: 5.0000e-04
# Epoch 20/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - correlation_coefficient: 0.8321 - loss: 0.2099 - mae: 0.1999 - val_correlation_coefficient: -0.8865 - val_loss: 0.6223 - val_mae: 0.6385 - learning_rate: 5.0000e-04
# Epoch 21/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - correlation_coefficient: 0.8658 - loss: 0.1886 - mae: 0.1625 - val_correlation_coefficient: -0.8783 - val_loss: 0.6298 - val_mae: 0.6462 - learning_rate: 5.0000e-04
# Epoch 22/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - correlation_coefficient: 0.8638 - loss: 0.1703 - mae: 0.1657 - val_correlation_coefficient: -0.8744 - val_loss: 0.6319 - val_mae: 0.6488 - learning_rate: 2.5000e-04
# Epoch 23/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - correlation_coefficient: 0.8661 - loss: 0.1794 - mae: 0.1750 - val_correlation_coefficient: -0.8695 - val_loss: 0.6341 - val_mae: 0.6510 - learning_rate: 2.5000e-04
# Epoch 24/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8726 - loss: 0.1819 - mae: 0.1605 - val_correlation_coefficient: -0.8656 - val_loss: 0.6378 - val_mae: 0.6537 - learning_rate: 2.5000e-04
# Epoch 25/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.8733 - loss: 0.1588 - mae: 0.1482 - val_correlation_coefficient: -0.8631 - val_loss: 0.6393 - val_mae: 0.6553 - learning_rate: 2.5000e-04
# Epoch 26/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.8671 - loss: 0.1672 - mae: 0.1570 - val_correlation_coefficient: -0.8608 - val_loss: 0.6422 - val_mae: 0.6586 - learning_rate: 2.5000e-04
# Epoch 27/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.8714 - loss: 0.1578 - mae: 0.1429 - val_correlation_coefficient: -0.8595 - val_loss: 0.6434 - val_mae: 0.6604 - learning_rate: 2.5000e-04
# Epoch 28/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.8646 - loss: 0.1880 - mae: 0.2025 - val_correlation_coefficient: -0.8591 - val_loss: 0.6416 - val_mae: 0.6593 - learning_rate: 2.5000e-04
# Epoch 29/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8694 - loss: 0.1751 - mae: 0.1684 - val_correlation_coefficient: -0.8578 - val_loss: 0.6392 - val_mae: 0.6571 - learning_rate: 2.5000e-04
# Epoch 30/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - correlation_coefficient: 0.8763 - loss: 0.1566 - mae: 0.1468 - val_correlation_coefficient: -0.8560 - val_loss: 0.6350 - val_mae: 0.6535 - learning_rate: 2.5000e-04
# Epoch 31/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8760 - loss: 0.1543 - mae: 0.1487 - val_correlation_coefficient: -0.8538 - val_loss: 0.6284 - val_mae: 0.6480 - learning_rate: 2.5000e-04
# Epoch 32/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.8739 - loss: 0.1576 - mae: 0.1458 - val_correlation_coefficient: -0.8525 - val_loss: 0.6263 - val_mae: 0.6461 - learning_rate: 1.2500e-04
# Epoch 33/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.8417 - loss: 0.1696 - mae: 0.1460 - val_correlation_coefficient: -0.8511 - val_loss: 0.6256 - val_mae: 0.6457 - learning_rate: 1.2500e-04
# Epoch 34/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.8851 - loss: 0.1415 - mae: 0.1106 - val_correlation_coefficient: -0.8495 - val_loss: 0.6255 - val_mae: 0.6460 - learning_rate: 1.2500e-04
# Epoch 35/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - correlation_coefficient: 0.8616 - loss: 0.1757 - mae: 0.1573 - val_correlation_coefficient: -0.8481 - val_loss: 0.6261 - val_mae: 0.6472 - learning_rate: 1.2500e-04
# Epoch 36/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.8626 - loss: 0.1729 - mae: 0.1444 - val_correlation_coefficient: -0.8467 - val_loss: 0.6283 - val_mae: 0.6497 - learning_rate: 1.2500e-04
# Epoch 37/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - correlation_coefficient: 0.8742 - loss: 0.1754 - mae: 0.1494 - val_correlation_coefficient: -0.8453 - val_loss: 0.6312 - val_mae: 0.6529 - learning_rate: 1.2500e-04
# Epoch 38/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8766 - loss: 0.1488 - mae: 0.1359 - val_correlation_coefficient: -0.8437 - val_loss: 0.6332 - val_mae: 0.6553 - learning_rate: 1.2500e-04
# Epoch 39/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.8703 - loss: 0.1576 - mae: 0.1505 - val_correlation_coefficient: -0.8427 - val_loss: 0.6351 - val_mae: 0.6571 - learning_rate: 1.2500e-04
# Epoch 40/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - correlation_coefficient: 0.8542 - loss: 0.2031 - mae: 0.1806 - val_correlation_coefficient: -0.8414 - val_loss: 0.6375 - val_mae: 0.6590 - learning_rate: 1.2500e-04
# Epoch 41/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - correlation_coefficient: 0.8734 - loss: 0.1617 - mae: 0.1441 - val_correlation_coefficient: -0.8399 - val_loss: 0.6395 - val_mae: 0.6608 - learning_rate: 1.2500e-04
# Epoch 42/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - correlation_coefficient: 0.8751 - loss: 0.1572 - mae: 0.1583 - val_correlation_coefficient: -0.8396 - val_loss: 0.6394 - val_mae: 0.6609 - learning_rate: 6.2500e-05
# Epoch 43/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8570 - loss: 0.1845 - mae: 0.1643 - val_correlation_coefficient: -0.8396 - val_loss: 0.6385 - val_mae: 0.6604 - learning_rate: 6.2500e-05
# Epoch 44/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - correlation_coefficient: 0.8749 - loss: 0.1527 - mae: 0.1309 - val_correlation_coefficient: -0.8398 - val_loss: 0.6380 - val_mae: 0.6601 - learning_rate: 6.2500e-05
# Epoch 45/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - correlation_coefficient: 0.8739 - loss: 0.1631 - mae: 0.1442 - val_correlation_coefficient: -0.8397 - val_loss: 0.6378 - val_mae: 0.6601 - learning_rate: 6.2500e-05
# Epoch 46/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8776 - loss: 0.1668 - mae: 0.1461 - val_correlation_coefficient: -0.8394 - val_loss: 0.6374 - val_mae: 0.6599 - learning_rate: 6.2500e-05
# Epoch 47/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - correlation_coefficient: 0.8800 - loss: 0.1588 - mae: 0.1521 - val_correlation_coefficient: -0.8391 - val_loss: 0.6369 - val_mae: 0.6598 - learning_rate: 6.2500e-05
# Epoch 48/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.8788 - loss: 0.1576 - mae: 0.1425 - val_correlation_coefficient: -0.8388 - val_loss: 0.6357 - val_mae: 0.6591 - learning_rate: 6.2500e-05
# Epoch 49/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - correlation_coefficient: 0.8676 - loss: 0.1779 - mae: 0.1740 - val_correlation_coefficient: -0.8385 - val_loss: 0.6357 - val_mae: 0.6593 - learning_rate: 6.2500e-05
# Epoch 50/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.8747 - loss: 0.1564 - mae: 0.1487 - val_correlation_coefficient: -0.8384 - val_loss: 0.6363 - val_mae: 0.6600 - learning_rate: 6.2500e-05
# Epoch 51/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - correlation_coefficient: 0.8865 - loss: 0.1362 - mae: 0.1177 - val_correlation_coefficient: -0.8381 - val_loss: 0.6369 - val_mae: 0.6607 - learning_rate: 6.2500e-05
# Epoch 52/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - correlation_coefficient: 0.8683 - loss: 0.1781 - mae: 0.1764 - val_correlation_coefficient: -0.8381 - val_loss: 0.6374 - val_mae: 0.6612 - learning_rate: 3.1250e-05
# Epoch 53/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - correlation_coefficient: 0.8750 - loss: 0.1644 - mae: 0.1312 - val_correlation_coefficient: -0.8382 - val_loss: 0.6382 - val_mae: 0.6618 - learning_rate: 3.1250e-05
# Epoch 54/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - correlation_coefficient: 0.8743 - loss: 0.1530 - mae: 0.1356 - val_correlation_coefficient: -0.8383 - val_loss: 0.6376 - val_mae: 0.6615 - learning_rate: 3.1250e-05
# Epoch 55/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8775 - loss: 0.1671 - mae: 0.1420 - val_correlation_coefficient: -0.8383 - val_loss: 0.6373 - val_mae: 0.6615 - learning_rate: 3.1250e-05
# Epoch 56/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.8418 - loss: 0.1926 - mae: 0.1726 - val_correlation_coefficient: -0.8383 - val_loss: 0.6371 - val_mae: 0.6616 - learning_rate: 3.1250e-05
# Epoch 57/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8791 - loss: 0.1555 - mae: 0.1324 - val_correlation_coefficient: -0.8383 - val_loss: 0.6370 - val_mae: 0.6616 - learning_rate: 3.1250e-05
# Epoch 58/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.8869 - loss: 0.1334 - mae: 0.0980 - val_correlation_coefficient: -0.8383 - val_loss: 0.6370 - val_mae: 0.6617 - learning_rate: 3.1250e-05
# Epoch 59/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - correlation_coefficient: 0.8456 - loss: 0.2073 - mae: 0.1872 - val_correlation_coefficient: -0.8385 - val_loss: 0.6370 - val_mae: 0.6618 - learning_rate: 3.1250e-05
# Epoch 60/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - correlation_coefficient: 0.8825 - loss: 0.1627 - mae: 0.1344 - val_correlation_coefficient: -0.8387 - val_loss: 0.6375 - val_mae: 0.6622 - learning_rate: 3.1250e-05
# Epoch 61/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - correlation_coefficient: 0.8724 - loss: 0.1755 - mae: 0.1616 - val_correlation_coefficient: -0.8389 - val_loss: 0.6378 - val_mae: 0.6625 - learning_rate: 3.1250e-05
# Epoch 62/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - correlation_coefficient: 0.8624 - loss: 0.1853 - mae: 0.1614 - val_correlation_coefficient: -0.8388 - val_loss: 0.6379 - val_mae: 0.6627 - learning_rate: 1.5625e-05
# Epoch 63/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.8754 - loss: 0.1599 - mae: 0.1488 - val_correlation_coefficient: -0.8388 - val_loss: 0.6377 - val_mae: 0.6626 - learning_rate: 1.5625e-05
# Epoch 64/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - correlation_coefficient: 0.8757 - loss: 0.1593 - mae: 0.1412 - val_correlation_coefficient: -0.8387 - val_loss: 0.6376 - val_mae: 0.6625 - learning_rate: 1.5625e-05
# Epoch 65/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - correlation_coefficient: 0.8792 - loss: 0.1666 - mae: 0.1581 - val_correlation_coefficient: -0.8388 - val_loss: 0.6373 - val_mae: 0.6623 - learning_rate: 1.5625e-05
# Epoch 66/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8715 - loss: 0.1572 - mae: 0.1514 - val_correlation_coefficient: -0.8389 - val_loss: 0.6371 - val_mae: 0.6621 - learning_rate: 1.5625e-05
# Epoch 67/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - correlation_coefficient: 0.8864 - loss: 0.1444 - mae: 0.1176 - val_correlation_coefficient: -0.8390 - val_loss: 0.6370 - val_mae: 0.6619 - learning_rate: 1.5625e-05
# Epoch 68/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - correlation_coefficient: 0.8685 - loss: 0.1626 - mae: 0.1545 - val_correlation_coefficient: -0.8392 - val_loss: 0.6365 - val_mae: 0.6615 - learning_rate: 1.5625e-05
# Epoch 69/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - correlation_coefficient: 0.8773 - loss: 0.1653 - mae: 0.1423 - val_correlation_coefficient: -0.8394 - val_loss: 0.6364 - val_mae: 0.6614 - learning_rate: 1.5625e-05
# Epoch 70/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8767 - loss: 0.1511 - mae: 0.1276 - val_correlation_coefficient: -0.8395 - val_loss: 0.6364 - val_mae: 0.6614 - learning_rate: 1.5625e-05
# Epoch 71/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - correlation_coefficient: 0.8373 - loss: 0.2139 - mae: 0.1999 - val_correlation_coefficient: -0.8398 - val_loss: 0.6365 - val_mae: 0.6615 - learning_rate: 1.5625e-05
# Epoch 72/700
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - correlation_coefficient: 0.8734 - loss: 0.1759 - mae: 0.1528 - val_correlation_coefficient: -0.8399 - val_loss: 0.6367 - val_mae: 0.6617 - learning_rate: 1.0000e-05

# %%
# Evaluate the model
y_pred_scaled = model.predict(X_test_seq)
y_pred = target_scaler.inverse_transform(y_pred_scaled)
y_test_unscaled = target_scaler.inverse_transform(y_test_seq)

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

r2 = r2_score(y_test_unscaled, y_pred)
rmse = np.sqrt(mean_squared_error(y_test_unscaled, y_pred))
mae = mean_absolute_error(y_test_unscaled, y_pred)
rmae= np.sqrt(mean_absolute_error(y_test_unscaled, y_pred))
corr_coef = np.corrcoef(y_test_unscaled.flatten(), y_pred.flatten())[0,1]


residual_en = np.abs(y_test_unscaled-y_pred)
R2 = 1 - (residual_en/np.sum(np.sqrt(residual_en)))
np.average(R2)
print('R2 :'," ", np.average(R2))



print("\nTest Metrics:")
print('R2 :'," ", np.average(R2))
# print(f"R2: {r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"RMAE:{rmae:.4f}")

print(f"\nPrediction Range:")
print(f"Min: {y_pred.min():.4f}, Max: {y_pred.max():.4f}")

print(f"\nCorrelation coefficient: {corr_coef:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# R2 :   0.9967090829772575
#
# Test Metrics:
# R2 :   0.9967090829772575
# RMSE: 0.0007
# MAE: 0.0007
# RMAE:0.0257
#
# Prediction Range:
# Min: 0.0600, Max: 0.0604
#
# Correlation coefficient: -0.8381

# %%
y_test_unscaled
# Out:
# array([[0.06066183],
#        [0.06067276],
#        [0.06070957],
#        [0.06076996],
#        [0.060842  ],
#        [0.06092494],
#        [0.06102614],
#        [0.06112592]])

# %%
y_pred
# Out:
# array([[0.06024276],
#        [0.06028195],
#        [0.06036384],
#        [0.06036003],
#        [0.06015055],
#        [0.06002497],
#        [0.05998288],
#        [0.0600469 ]], dtype=float32)

# %%
import seaborn as sns

# %%
plt.figure(1)
# plt.style.use('seaborn')
plt.figure(figsize=(7,5))
sns.set(font_scale=1.2)
plt.plot(y_train_raw,'--', color='black',markersize=12, linewidth=2.5)
plt.plot(df[53:].index, y_test_unscaled,'-',color='orange',markersize=12, linewidth=2.5)
plt.plot(df[53:].index,y_pred,'-', color='steelblue', markersize=12, linewidth=2.5)
# # plt.title('Measured against model data')
# plt.xlabel('Time (years)')
# plt.ylabel('Surface temp. change,\N{DEGREE SIGN}C')
# # plt.legend(['Share of life Expectancy','Lasso Model prediction ' ])
# # plt.ylim(70, 80)
# plt.legend(['Surface temp. change (train set)','Surface temp. change(test set)','LSTM model prediction'  ])

# x = [ 0, 10,20,30,40,50,61]

# labels = [1961, 1970, 1980, 1990, 2000,2010, 2021]
# plt.xticks(x, labels, rotation='horizontal')
# plt.savefig("Surface temp. change_LSTM.png", dpi = 1000, bbox_inches='tight')

# %%
df[52:]
# Out:
#     Indicator Code  FP index   LP index   Vegetal Pds-FS  Cereals -FS  \
# 52            2013      95.84      98.85            2697          783
# 53            2014      98.16      99.02            2734          788
# 54            2015      96.99      98.61            2731          790
# 55            2016     104.85     102.38            2743          783
# 56            2017     101.95     105.14            2752          782
# 57            2018     103.35     108.11            2743          795
# 58            2019     100.09     109.27            2782          802
# 59            2020     104.45     111.14            2801          814
# 60            2021     105.00     112.00            2818          818
#
#     Starchy Rts-FS  Pulses-FS  Fruits -FS  Meat-FS  Fish-FS  ...   Energy use  \
# 52             102         37         130      431       28  ...  6905.598633
# 53             102         30         118      428       28  ...  6960.683997
# 54              99         31         121      435       29  ...  6803.996607
# 55             102         32         130      441       28  ...  6906.045291
# 56             103         32         146      445       29  ...  6865.181738
# 57             102         32         153      488       29  ...  6206.663228
# 58             100         31         155      499       30  ...  6563.464324
# 59             101         44         144      510       30  ...  7661.265745
# 60              95         46         148      508       30  ...  7891.000000
#
#     Renewable energy      GHGEs   Agricultural land use share   \
# 52           7.134616  19.724750                     44.124682
# 53           7.262891  19.774370                     44.184360
# 54           7.468743  19.143078                     44.244027
# 55           8.285085  18.617743                     44.303705
# 56           9.082048  18.431720                     44.363367
# 57           8.964108  18.884752                     44.363367
# 58           9.314181  18.479849                     44.363367
# 59          10.528127  16.749628                     44.363367
# 60          10.506885  17.583845                     44.363367
#
#     Agricultural water share   Surface temp.  Overweight      Obese  \
# 52                  38.141533       0.060652   65.800000  34.700000
# 53                  38.886310       0.060662   66.400000  35.400000
# 54                  39.658783       0.060673   66.900000  36.000000
# 55                  39.658783       0.060710   67.400000  36.700000
# 56                  39.658783       0.060770   67.900000  37.300000
# 57                  39.658783       0.060842   68.737227  37.533824
# 58                  39.658783       0.060925   69.544949  37.914569
# 59                  40.231326       0.061026   70.651154  38.130126
# 60                  40.653711       0.061126   70.903764  38.698860
#
#     Death-NCD   Life expectancy
# 52   30.840206           78.9507
# 53   30.755196           79.0175
# 54   30.838190           78.8694
# 55   30.633383           78.8482
# 56   30.534817           78.8213
# 57   30.594480           78.9896
# 58   30.099432           79.1380
# 59   26.972640           77.4144
# 60   27.372815           77.1982
#
# [9 rows x 34 columns]

# %%
# Plot training & validation loss
# plt.style.use('seaborn')
# plt.figure(figsize=(7,5))
sns.set(font_scale=1.2)

plt.figure(figsize=(5,4))
plt.plot(history.history['loss'], label='Training Loss', linewidth=3, color='orange')
plt.plot(history.history['val_loss'], label='Validation Loss-BiLSTM', linewidth=3, color='steelblue')
# plt.title('Model Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.tight_layout()
# plt.savefig('Bidirection on GHGE_validation_loss.png', dpi = 1000, bbox_inches='tight')
plt.show()

# %%
# Plot training & validation MAE
# plt.style.use('seaborn')
# plt.figure(figsize=(7,5))
sns.set(font_scale=1.2)

plt.figure(figsize=(5,4))
plt.plot(history.history['mae'], label='Training MAE', linewidth=3, color='orange')
plt.plot(history.history['val_mae'], label='Validation MAE-BiLSTM', linewidth=3, color='steelblue')
# plt.title('Model MAE over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.tight_layout()
# plt.savefig('Bidirection on GHGE_MAE_loss.png', dpi = 1000, bbox_inches='tight')
plt.show()
